# %% [markdown]
# # Agent Deployment and Security Workflow (Cloud Run & Agent Engine)
#
# This notebook demonstrates deploying an AI Agent to both Google Cloud Run and Vertex AI Agent Engine, focusing on the integration of **Model Armor** for responsible AI/security filtering. It also illustrates a common deployment issue related to Google Cloud Storage (GCS) permissions on the Agent Engine's custom code service account and how to resolve it.

# %%
# 1. Setup and Installation
# This cell installs all the necessary Python libraries for Google Cloud services,
# including Vertex AI, Model Armor, and the Google Agent Development Kit (ADK).

# !pip install pyyaml
# !pip install cloudpickle==3.1.1
# !pip install google-cloud-api-keys
# !pip install uvicorn
# !pip install fastapi
# !pip install python-dotenv
# !pip install google-adk
# !pip install --upgrade google-cloud-aiplatform
# !pip install --upgrade google-cloud-modelarmor
# !pip install google-genai
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (6.0.2)
# Requirement already satisfied: cloudpickle==3.1.1 in /usr/local/lib/python3.10/dist-packages (3.1.1)
# Requirement already satisfied: google-cloud-api-keys in /usr/local/lib/python3.10/dist-packages (0.5.17)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-api-keys) (2.25.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-api-keys) (2.27.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-api-keys) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-api-keys) (6.32.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-api-keys) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-api-keys) (2.32.5)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-api-keys) (1.69.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-api-keys) (1.62.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-api-keys) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-api-keys) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-api-keys) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-api-keys) (0.6.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-api-keys) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-api-keys) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-api-keys) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-api-keys) (2024.12.14)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.10/dist-packages (0.35.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn) (8.1.8)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn) (0.14.0)
# Requirement already satisfied: typing-extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn) (4.14.1)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.10/dist-packages (0.116.1)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in /usr/local/lib/python3.10/dist-packages (from fastapi) (0.47.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from fastapi) (2.11.7)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from fastapi) (4.14.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.4.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.10/dist-packages (from starlette<0.48.0,>=0.40.0->fastapi) (4.10.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi) (1.3.1)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (1.1.1)
# Requirement already satisfied: google-adk in /usr/local/lib/python3.10/dist-packages (1.14.0)
# Requirement already satisfied: PyYAML<7.0.0,>=6.0.2 in /usr/local/lib/python3.10/dist-packages (from google-adk) (6.0.2)
# Requirement already satisfied: absolufy-imports<1.0.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from google-adk) (0.3.1)
# Requirement already satisfied: anyio<5.0.0,>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from google-adk) (4.10.0)
# Requirement already satisfied: authlib<2.0.0,>=1.5.1 in /usr/local/lib/python3.10/dist-packages (from google-adk) (1.6.3)
# Requirement already satisfied: click<9.0.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from google-adk) (8.1.8)
# Requirement already satisfied: fastapi<1.0.0,>=0.115.0 in /usr/local/lib/python3.10/dist-packages (from google-adk) (0.116.1)
# Requirement already satisfied: google-api-python-client<3.0.0,>=2.157.0 in /usr/local/lib/python3.10/dist-packages (from google-adk) (2.181.0)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.95.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.95.1->google-adk) (1.114.0)
# Requirement already satisfied: google-cloud-bigtable>=2.32.0 in /usr/local/lib/python3.10/dist-packages (from google-adk) (2.32.0)
# Requirement already satisfied: google-cloud-secret-manager<3.0.0,>=2.22.0 in /usr/local/lib/python3.10/dist-packages (from google-adk) (2.24.0)
# Requirement already satisfied: google-cloud-spanner<4.0.0,>=3.56.0 in /usr/local/lib/python3.10/dist-packages (from google-adk) (3.57.0)
# Requirement already satisfied: google-cloud-speech<3.0.0,>=2.30.0 in /usr/local/lib/python3.10/dist-packages (from google-adk) (2.33.0)
# Requirement already satisfied: google-cloud-storage<3.0.0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-adk) (2.19.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from google-adk) (1.31.0)
# Requirement already satisfied: graphviz<1.0.0,>=0.20.2 in /usr/local/lib/python3.10/dist-packages (from google-adk) (0.20.3)
# Requirement already satisfied: mcp<2.0.0,>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from google-adk) (1.14.0)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.31.0 in /usr/local/lib/python3.10/dist-packages (from google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-gcp-trace<2.0.0,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-adk) (1.9.0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.31.0 in /usr/local/lib/python3.10/dist-packages (from google-adk) (1.37.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from google-adk) (2.11.7)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0.post0 in /usr/local/lib/python3.10/dist-packages (from google-adk) (2.9.0.post0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from google-adk) (1.1.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in /usr/local/lib/python3.10/dist-packages (from google-adk) (2.32.5)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from google-adk) (2.0.36)
# Requirement already satisfied: sqlalchemy-spanner>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from google-adk) (1.16.0)
# Requirement already satisfied: starlette<1.0.0,>=0.46.2 in /usr/local/lib/python3.10/dist-packages (from google-adk) (0.47.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from google-adk) (8.5.0)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /usr/local/lib/python3.10/dist-packages (from google-adk) (4.14.1)
# Requirement already satisfied: tzlocal<6.0,>=5.3 in /usr/local/lib/python3.10/dist-packages (from google-adk) (5.3.1)
# Requirement already satisfied: uvicorn<1.0.0,>=0.34.0 in /usr/local/lib/python3.10/dist-packages (from google-adk) (0.35.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from google-adk) (6.0.0)
# Requirement already satisfied: websockets<16.0.0,>=15.0.1 in /usr/local/lib/python3.10/dist-packages (from google-adk) (15.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0.0,>=4.9.0->google-adk) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0.0,>=4.9.0->google-adk) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0.0,>=4.9.0->google-adk) (1.3.1)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.10/dist-packages (from authlib<2.0.0,>=1.5.1->google-adk) (43.0.3)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.27.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.25.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.1.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.95.1->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.95.1->google-adk) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.95.1->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.95.1->google-adk) (6.32.0)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.95.1->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.95.1->google-adk) (24.2)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.95.1->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.95.1->google-adk) (3.31.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.95.1->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.95.1->google-adk) (1.14.2)
# Requirement already satisfied: shapely<3.0.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.95.1->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.95.1->google-adk) (2.0.6)
# Requirement already satisfied: docstring_parser<1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.95.1->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.95.1->google-adk) (0.16)
# Requirement already satisfied: cloudpickle<4.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.95.1->google-adk) (3.1.1)
# Requirement already satisfied: google-cloud-trace<2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.95.1->google-adk) (1.16.2)
# Requirement already satisfied: google-cloud-logging<4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.95.1->google-adk) (3.12.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigtable>=2.32.0->google-adk) (2.4.1)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigtable>=2.32.0->google-adk) (0.14.2)
# Requirement already satisfied: google-crc32c<2.0.0dev,>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigtable>=2.32.0->google-adk) (1.6.0)
# Requirement already satisfied: sqlparse>=0.4.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.5.3)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.15.4)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage<3.0.0,>=2.18.0->google-adk) (2.7.2)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.10/dist-packages (from google-genai<2.0.0,>=1.21.1->google-adk) (0.28.1)
# Requirement already satisfied: httpx-sse>=0.4 in /usr/local/lib/python3.10/dist-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.4.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /usr/local/lib/python3.10/dist-packages (from mcp<2.0.0,>=1.8.0->google-adk) (4.23.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /usr/local/lib/python3.10/dist-packages (from mcp<2.0.0,>=1.8.0->google-adk) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.10/dist-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from mcp<2.0.0,>=1.8.0->google-adk) (3.0.2)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api<2.0.0,>=1.31.0->google-adk) (8.5.0)
# Requirement already satisfied: opentelemetry-resourcedetector-gcp==1.*,>=1.5.0dev0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-gcp-trace<2.0.0,>=1.9.0->google-adk) (1.9.0a0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-sdk<2.0.0,>=1.31.0->google-adk) (0.58b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.0->google-adk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.0->google-adk) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.0->google-adk) (0.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.9.0.post0->google-adk) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.32.4->google-adk) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.32.4->google-adk) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.32.4->google-adk) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy<3.0.0,>=2.0->google-adk) (3.1.1)
# Requirement already satisfied: alembic in /usr/local/lib/python3.10/dist-packages (from sqlalchemy-spanner>=1.14.0->google-adk) (1.16.5)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn<1.0.0,>=0.34.0->google-adk) (0.14.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.95.1->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.95.1->google-adk) (1.69.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.95.1->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.95.1->google-adk) (1.62.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.9)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.95.1->google-adk) (1.6.2)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.95.1->google-adk) (0.3.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (3.2.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.21.1->google-adk) (1.0.7)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.31.0->google-adk) (3.21.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (0.22.3)
# Requirement already satisfied: numpy<3,>=1.14 in /usr/local/lib/python3.10/dist-packages (from shapely<3.0.0->google-cloud-aiplatform<2.0.0,>=1.95.1->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.95.1->google-adk) (1.26.4)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic->sqlalchemy-spanner>=1.14.0->google-adk) (1.3.10)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from alembic->sqlalchemy-spanner>=1.14.0->google-adk) (2.2.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography->authlib<2.0.0,>=1.5.1->google-adk) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography->authlib<2.0.0,>=1.5.1->google-adk) (2.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.6.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic->sqlalchemy-spanner>=1.14.0->google-adk) (3.0.2)
# Requirement already satisfied: google-cloud-aiplatform in /usr/local/lib/python3.10/dist-packages (1.114.0)
# Collecting google-cloud-aiplatform
#   Downloading google_cloud_aiplatform-1.118.0-py2.py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (2.25.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (2.27.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (6.32.0)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (24.2)
# Requirement already satisfied: google-cloud-storage<3.0.0,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (2.19.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (3.31.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (1.14.2)
# Requirement already satisfied: shapely<3.0.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (2.0.6)
# Collecting google-genai<2.0.0,>=1.37.0 (from google-cloud-aiplatform)
#   Downloading google_genai-1.40.0-py3-none-any.whl.metadata (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (2.11.7)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (4.14.1)
# Requirement already satisfied: docstring_parser<1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (0.16)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (2.32.5)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.69.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.62.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.7.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.9.0.post0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-resource-manager<3.0.0,>=1.3.3->google-cloud-aiplatform) (0.14.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage<3.0.0,>=1.32.0->google-cloud-aiplatform) (1.6.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform) (4.10.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.10/dist-packages (from google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform) (0.28.1)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.10/dist-packages (from google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform) (8.5.0)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform) (15.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3->google-cloud-aiplatform) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3->google-cloud-aiplatform) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3->google-cloud-aiplatform) (0.4.1)
# Requirement already satisfied: numpy<3,>=1.14 in /usr/local/lib/python3.10/dist-packages (from shapely<3.0.0->google-cloud-aiplatform) (1.26.4)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform) (1.3.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform) (0.14.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform) (0.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (2.3.0)
# Downloading google_cloud_aiplatform-1.118.0-py2.py3-none-any.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 53.0 MB/s eta 0:00:00
# Downloading google_genai-1.40.0-py3-none-any.whl (245 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.1/245.1 kB 16.7 MB/s eta 0:00:00
# Installing collected packages: google-genai, google-cloud-aiplatform
#   Attempting uninstall: google-genai
#     Found existing installation: google-genai 1.31.0
#     Uninstalling google-genai-1.31.0:
#       Successfully uninstalled google-genai-1.31.0
#   Attempting uninstall: google-cloud-aiplatform
#     Found existing installation: google-cloud-aiplatform 1.114.0
#     Uninstalling google-cloud-aiplatform-1.114.0:
#       Successfully uninstalled google-cloud-aiplatform-1.114.0
# Successfully installed google-cloud-aiplatform-1.118.0 google-genai-1.40.0
# Requirement already satisfied: google-cloud-modelarmor in /usr/local/lib/python3.10/dist-packages (0.2.8)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-modelarmor) (2.25.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-modelarmor) (2.27.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-modelarmor) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-modelarmor) (6.32.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-modelarmor) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-modelarmor) (2.32.5)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-modelarmor) (1.69.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-modelarmor) (1.62.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-modelarmor) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-modelarmor) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-modelarmor) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-modelarmor) (0.6.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-modelarmor) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-modelarmor) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-modelarmor) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-modelarmor) (2024.12.14)
# Requirement already satisfied: google-genai in /usr/local/lib/python3.10/dist-packages (1.40.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from google-genai) (4.10.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-genai) (2.27.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.10/dist-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-genai) (2.11.7)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.10/dist-packages (from google-genai) (2.32.5)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.10/dist-packages (from google-genai) (8.5.0)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /usr/local/lib/python3.10/dist-packages (from google-genai) (4.14.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (4.9)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-genai) (0.6.1)

# %% [markdown]
# # 2. Configuration Variables
#
# Set your Google Cloud project details and deployment locations. The `BUCKET` variable is crucial as it serves as the staging location for the Agent Engine deployment, and its permissions will be tested later.

# %%
# Update the variable values below with your specific project details.

PROJECT_ID = "data-vpc-sc-demo"  # @param {type:"string"}
PROJECT_NUMBER = "1083677030545"  # @param {type:"string"} # Get this from Project settings in GCP Console
LOCATION = "us-central1" # @param {type:"string"}

# BUCKET is used for storing the agent code package during Agent Engine deployment.
# IMPORTANT: This bucket MUST exist in your project and be in the same region as the deployment.
# We will use a dynamically generated bucket name based on the PROJECT_ID.
BUCKET_NAME = f"{PROJECT_ID}-agent-artifacts"
BUCKET = f"gs://{BUCKET_NAME}"

# Model Armor Template ID (assuming you created this manually)
MODEL_ARMOR_TEMPLATE_ID = "glean-poc-template" # @param {type:"string"}

print(f"Project ID: {PROJECT_ID}")
print(f"Deployment Location: {LOCATION}")
print(f"Agent Engine Staging Bucket: {BUCKET}")

# Ensure the bucket exists (optional, but good practice)
# !gsutil mb -p {PROJECT_ID} -l {LOCATION} {BUCKET}
# Out:
# Project ID: data-vpc-sc-demo
# Deployment Location: us-central1
# Agent Engine Staging Bucket: gs://data-vpc-sc-demo-agent-artifacts
# Creating gs://data-vpc-sc-demo-agent-artifacts/...

# %% [markdown]
# # 3. Authentication
#
# Authenticate your user session. This is required to execute Google Cloud commands and deploy resources.

# %%
from google.colab import auth

# Authenticate the user to access Google Cloud services
auth.authenticate_user(project_id=PROJECT_ID)

# Set the project for subsequent gcloud commands
# !gcloud config set project {PROJECT_ID}
# Out:
# WARNING: google.colab.auth.authenticate_user() is not supported in Colab Enterprise.
# Updated property [core/project].

# %% [markdown]
# # 4. Model Armor and DLP Setup (Prerequisites)
#
# Model Armor requires its API to be enabled and a template to be created in the GCP Console to define security and responsible AI policies (like DLP and harmful content filtering).
#
# ### 4.1 Enable Model Armor API

# %%
# Enable the Model Armor API
# !gcloud services enable modelarmor.googleapis.com --project={PROJECT_ID}

# %% [markdown]
# ### 4.2 Manual Step: Create Model Armor Template and DLP Configuration
#
# **Note:** The following steps are typically performed manually in the Google Cloud Console or via the API/gcloud before running this notebook.
#
# 1.  **Create Sensitive Data Protection (DLP) Inspection Template** (e.g., ID: `sensitive_data_protection`) in the DLP console.
# 2.  **Create Model Armor Template** (ID: `glean-poc-template`) in the Model Armor console, linking the DLP template and setting Responsible AI confidence thresholds.

# %% [markdown]
# # 5. Stage 1: Cloud Run Deployment
#
# This section clones a sample agent repository, configures the environment variables (including the Model Armor template ID), and deploys the agent as a containerized service using Cloud Run.

# %%
CLOUD_RUN_SERVICE_NAME = "capital-agent-service"

# Clone Repository and Prepare Environment
# %cd /content/
# !rm -rf ai-agent
# !git clone https://github.com/avnit/ai-agent.git
# %cd ai-agent/

# Create .env file with Model Armor settings for the agent to use
# !echo "GOOGLE_CLOUD_PROJECT={PROJECT_ID}" > modelarmor/.env
# !echo "GOOGLE_CLOUD_LOCATION={LOCATION}" >> modelarmor/.env
# !echo "AIP_ENDPOINT_ID={MODEL_ARMOR_TEMPLATE_ID}" >> modelarmor/.env
# !echo "GOOGLE_GENAI_USE_VERTEXAI=true" >> modelarmor/.env

# Deploy to Cloud Run
# !gcloud run deploy {CLOUD_RUN_SERVICE_NAME} \
--source . \
--region {LOCATION} \
--project {PROJECT_ID} \
--allow-unauthenticated \
--set-env-vars="GOOGLE_CLOUD_PROJECT={PROJECT_ID},GOOGLE_CLOUD_LOCATION={LOCATION},AIP_ENDPOINT_ID={MODEL_ARMOR_TEMPLATE_ID},GOOGLE_GENAI_USE_VERTEXAI=true"
# Out:
# /content
# Cloning into 'ai-agent'...
# remote: Enumerating objects: 132, done.
# remote: Counting objects: 100% (132/132), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 132 (delta 58), reused 99 (delta 33), pack-reused 0 (from 0)
# Receiving objects: 100% (132/132), 1.67 MiB | 10.60 MiB/s, done.
# Resolving deltas: 100% (58/58), done.
# /content/ai-agent
# Building using Dockerfile and deploying container to Cloud Run service [capital-agent-service] in project [data-vpc-sc-demo] region [us-central1]
#   Setting IAM policy failed, try "gcloud beta run services add-iam-policy-binding --region=us-central1 --member=allUsers --role=roles/run.invoker capital-agent-service"
# Service [capital-agent-service] revision [capital-agent-service-00010-gg9] has been deployed and is serving 100 percent of traffic.
# Service URL: https://capital-agent-service-1083677030545.us-central1.run.app

# %% [markdown]
# # 6. Stage 2: Agent Engine Deployment (Permission Denied Scenario)
#
# Vertex AI Agent Engine deployment requires the Vertex AI Custom Code Service Agent to have read/write access to the staging GCS bucket. We will first identify this service account and then simulate a deployment *failure* due to missing permissions.

# %%
# Identify the Vertex AI Custom Code Service Account
# This service account requires permissions on the GCS bucket.
SERVICE_AGENT = f"service-{PROJECT_NUMBER}@gcp-sa-aiplatform-customcode.iam.gserviceaccount.com"
print(f"Vertex AI Custom Code Service Account: {SERVICE_AGENT}")

# Clone and Prepare Agent Engine Repository
# %cd /content/
# !rm -rf ai-agent-deploy-ae
# !git clone https://github.com/avnit/ai-agent-deploy-ae/
# %cd ai-agent-deploy-ae/labs/AgentEngineDeploy/

# Configure .env for Agent Engine
# !echo "GOOGLE_CLOUD_PROJECT={PROJECT_ID}" > .env
# !echo "GOOGLE_CLOUD_LOCATION={LOCATION}" >> .env
# !echo "AIP_ENDPOINT_ID={MODEL_ARMOR_TEMPLATE_ID}" >> .env
# !echo "GOOGLE_GENAI_USE_VERTEXAI=true" >> .env

# --- ATTEMPT DEPLOYMENT (EXPECTED TO FAIL) ---
# The staging bucket permissions for the Service Agent are currently insufficient.

AGENT_DISPLAY_NAME_FAIL = "adk-agent-test-fail"
print("\n--- ATTEMPTING DEPLOYMENT (EXPECTED TO FAIL: 403 Permission Denied) ---")

# The adk deploy command will fail if the service account does not have Storage Object Admin access to the bucket.
# !adk deploy agent_engine \
    --project={PROJECT_ID} \
    --region={LOCATION} \
    --staging_bucket={BUCKET} \
    --display_name={AGENT_DISPLAY_NAME_FAIL} \
    .

# The expected output from the `adk deploy` command would be similar to:
# Deploy failed: 403 GET https://storage.googleapis.com/storage/v1/b/... Permission 'storage.buckets.get' denied...
# Out:
# Vertex AI Custom Code Service Account: service-1083677030545@gcp-sa-aiplatform-customcode.iam.gserviceaccount.com
# /content
# Cloning into 'ai-agent-deploy-ae'...
# remote: Enumerating objects: 81, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 81 (delta 32), reused 61 (delta 14), pack-reused 0 (from 0)
# Receiving objects: 100% (81/81), 28.50 KiB | 1.58 MiB/s, done.
# Resolving deltas: 100% (32/32), done.
# /content/ai-agent-deploy-ae/labs/AgentEngineDeploy
#
# --- ATTEMPTING DEPLOYMENT (EXPECTED TO FAIL: 403 Permission Denied) ---
# Copying agent source code...
# Copying agent source code complete.
# Initializing Vertex AI...
# Resolving files and dependencies...
# Reading environment variables from /content/ai-agent-deploy-ae/labs/AgentEngineDeploy/.env
# Ignoring GOOGLE_CLOUD_PROJECT in .env as `--project` was explicitly passed and takes precedence
# Ignoring GOOGLE_CLOUD_LOCATION in .env as `--region` was explicitly passed and takes precedence
# Vertex AI initialized.
# Created /tmp/agent_engine_deploy_src/20251002_185206/agent_engine_app.py
# Files and dependencies resolved
# Running `absolufy-imports /tmp/agent_engine_deploy_src/20251002_185206/AgentEngineDeploy/agent.py`
# Running `absolufy-imports /tmp/agent_engine_deploy_src/20251002_185206/AgentEngineDeploy/deploy.py`
# Running `absolufy-imports /tmp/agent_engine_deploy_src/20251002_185206/AgentEngineDeploy/__init__.py`
# Deploying to agent engine...
# Reading requirements from requirements='/tmp/agent_engine_deploy_src/20251002_185206/AgentEngineDeploy/requirements.txt'
# Read the following lines: ['uv', 'google-cloud', 'cloudpickle==3.1.1', 'google-cloud-aiplatform[agent_engines,adk,langchain,ag2,llama_index]==1.114.0', 'a2a-sdk>=0.3.4', 'pydantic==2.11.7', 'google-cloud-modelarmor']
# Identified the following requirements: {'cloudpickle': '3.1.1', 'pydantic': '2.11.7', 'google-cloud-aiplatform': '1.118.0'}
# The following requirements are incompatible: {'google-cloud-aiplatform==1.118.0 (required: ==1.114.0)'}
# The final list of requirements: ['uv', 'google-cloud', 'cloudpickle==3.1.1', 'google-cloud-aiplatform[agent_engines,adk,langchain,ag2,llama_index]==1.114.0', 'a2a-sdk>=0.3.4', 'pydantic==2.11.7', 'google-cloud-modelarmor']
# Using bucket data-vpc-sc-demo-agent-artifacts
# Wrote to gs://data-vpc-sc-demo-agent-artifacts/agent_engine/agent_engine.pkl
# Writing to gs://data-vpc-sc-demo-agent-artifacts/agent_engine/requirements.txt
# Creating in-memory tarfile of extra_packages
# Writing to gs://data-vpc-sc-demo-agent-artifacts/agent_engine/dependencies.tar.gz
# /usr/local/lib/python3.10/dist-packages/vertexai/preview/reasoning_engines/templates/adk.py:559: UserWarning: [EXPERIMENTAL] InMemoryCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   self._tmpl_attrs["credential_service"] = InMemoryCredentialService()
# /usr/local/lib/python3.10/dist-packages/google/adk/auth/credential_service/in_memory_credential_service.py:33: UserWarning: [EXPERIMENTAL] BaseCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   super().__init__()
# Creating AgentEngine
# Create AgentEngine backing LRO: projects/1083677030545/locations/us-central1/reasoningEngines/7969774849562247168/operations/3036557082456227840
# View progress and logs at https://console.cloud.google.com/logs/query?project=data-vpc-sc-demo
# AgentEngine created. Resource name: projects/1083677030545/locations/us-central1/reasoningEngines/7969774849562247168
# To use this AgentEngine in another session:
# agent_engine = vertexai.agent_engines.get('projects/1083677030545/locations/us-central1/reasoningEngines/7969774849562247168')
# Cleaning up the temp folder: /tmp/agent_engine_deploy_src/20251002_185206

# %% [markdown]
# # 7. Stage 3: Fix Permissions and Successful Redeployment
#
# We will now use the `gcloud storage` command to grant the necessary `Storage Object Admin` role (`roles/storage.objectAdmin`) to the Service Agent on the GCS bucket. Once permissions are granted, the redeployment should succeed.

# %%
# --- FIXING PERMISSIONS ---
# Grant the required Storage Object Admin role to the Service Account on the GCS bucket
print(f"\n--- FIXING PERMISSIONS ---")
print(f"Granting 'Storage Object Admin' role to {SERVICE_AGENT} on bucket {BUCKET}")

# !gcloud storage buckets add-iam-policy-binding {BUCKET} \
--member=serviceAccount:{SERVICE_AGENT} \
--role=roles/storage.objectAdmin \
--project={PROJECT_ID}

# --- REDEPLOYMENT (EXPECTED TO SUCCEED) ---
AGENT_DISPLAY_NAME_SUCCESS = "adk-agent-success"

print("\n--- REDEPLOYMENT (EXPECTED TO SUCCEED) ---")
# !adk deploy agent_engine \
    --project={PROJECT_ID} \
    --region={LOCATION} \
    --staging_bucket={BUCKET} \
    --display_name={AGENT_DISPLAY_NAME_SUCCESS} \
    .
# Out:
# --- FIXING PERMISSIONS ---
# Granting 'Storage Object Admin' role to service-1083677030545@gcp-sa-aiplatform-customcode.iam.gserviceaccount.com on bucket gs://data-vpc-sc-demo-agent-artifacts
# ERROR: (gcloud.storage.buckets.add-iam-policy-binding) HTTPError 400: Service account service-1083677030545@gcp-sa-aiplatform-customcode.iam.gserviceaccount.com does not exist.
#
# --- REDEPLOYMENT (EXPECTED TO SUCCEED) ---
# Copying agent source code...
# Copying agent source code complete.
# Initializing Vertex AI...
# Resolving files and dependencies...
# Vertex AI initialized.
# Created /tmp/agent_engine_deploy_src/20251002_204138/agent_engine_app.py
# Files and dependencies resolved
# Running `absolufy-imports /tmp/agent_engine_deploy_src/20251002_204138/ai-agent/main.py`
# Running `absolufy-imports /tmp/agent_engine_deploy_src/20251002_204138/ai-agent/deployment/deploy.py`
# Running `absolufy-imports /tmp/agent_engine_deploy_src/20251002_204138/ai-agent/modelarmor/agent.py`
# Running `absolufy-imports /tmp/agent_engine_deploy_src/20251002_204138/ai-agent/modelarmor/__init__.py`
# Deploying to agent engine...
# Reading requirements from requirements='/tmp/agent_engine_deploy_src/20251002_204138/ai-agent/requirements.txt'
# Read the following lines: ['google-cloud-aiplatform', 'uv', 'google-cloud-modelarmor', 'google-adk', 'pydantic==2.11.7', 'cloudpickle==3.1.1']
# Identified the following requirements: {'pydantic': '2.11.7', 'google-cloud-aiplatform': '1.118.0', 'cloudpickle': '3.1.1'}
# The final list of requirements: ['google-cloud-aiplatform', 'uv', 'google-cloud-modelarmor', 'google-adk', 'pydantic==2.11.7', 'cloudpickle==3.1.1']
# Using bucket data-vpc-sc-demo-agent-artifacts
# Wrote to gs://data-vpc-sc-demo-agent-artifacts/agent_engine/agent_engine.pkl
# Writing to gs://data-vpc-sc-demo-agent-artifacts/agent_engine/requirements.txt
# Creating in-memory tarfile of extra_packages
# Writing to gs://data-vpc-sc-demo-agent-artifacts/agent_engine/dependencies.tar.gz
# Cleaning up the temp folder: /tmp/agent_engine_deploy_src/20251002_204138
# Deploy failed: Failed to set up agent engine <vertexai.agent_engines._agent_engines.ModuleAgent object at 0x7b20e8d5e290>: invalid syntax (agent_engine_app.py, line 13)

# %% [markdown]
# # 8. Cleanup
#
# Remove the local cloned directories.

# %%
# Navigate back to the content directory and clean up
# %cd /content/
# !rm -rf ai-agent ai-agent-deploy-ae
